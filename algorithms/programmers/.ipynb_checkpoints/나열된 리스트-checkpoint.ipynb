# %%
def q(s):
    a = []
    for i in s:
        if a[-1:] == [i]: 
            continue
        a.append(i)
    return a

# %%
li = [1,1,4,4,1]
a = [1,4,1]
q(li)
# Out:
# [1, 4, 1]

# %%
li = [1]
i = 1

# %%
type([i])
# Out:
# int

# %%
i = 3

# %%
[3] == [i]
# Out:
# True

# %%
li = [1,2,3]
print(type(li[1:]))
# Out:
# <class 'int'>

# %%
li =[]

# %%
li[-1:]
# Out:
# []

# %%
li = [1,1,2,2,3,3] * 1000000

# %%
q(li)
# Out:
# [1,
#  2,
#  3,
#  1,
#  2,
#  3,
#  1,
#  2,
#  3,
#  1,
#  2,
#  3,
#  1,
#  2,
#  3,
#  1,
#  2,
#  3,
#  1,
#  2,
#  3,
#  1,
#  2,
#  3,
#  1,
#  2,
#  3,
#  1,
#  2,
#  3,
#  1,
#  2,
#  3,
#  1,
#  2,
#  3,
#  1,
#  2,
#  3,
#  1,
#  2,
#  3,
#  1,
#  2,
#  3,
#  1,
#  2,
#  3,
#  1,
#  2,
#  3,
#  1,
#  2,
#  3,
#  1,
#  2,
#  3,
#  1,
#  2,
#  3,
#  1,
#  2,
#  3,
#  1,
#  2,
#  3,
#  1,
#  2,
#  3,
#  1,
#  2,
#  3,
#  1,
#  2,
#  3,
#  1,
#  2,
#  3,
#  1,
#  2,
#  3,
#  1,
#  2,
#  3,
#  1,
#  2,
#  3,
#  1,
#  2,
#  3,
#  1,
#  2,
#  3,
#  1,
#  2,
#  3,
#  1,
#  2,
#  3,
#  1,
#  2,
#  3,
#  1,
#  2,
#  3,
#  1,
#  2,
#  3,
#  1,
#  2,
#  3,
#  1,
#  2,
#  3,
#  1,
#  2,
#  3,
#  1,
#  2,
#  3,
#  1,
#  2,
#  3,
#  1,
#  2,
#  3,
#  1,
#  2,
#  3,
#  1,
#  2,
#  3,
#  1,
#  2,
#  3,
#  1,
#  2,
#  3,
#  1,
#  2,
#  3,
#  1,
#  2,
#  3,
#  1,
#  2,
#  3,
#  1,
#  2,
#  3,
#  1,
#  2,
#  3,
#  1,
#  2,
#  3,
#  1,
#  2,
#  3,
#  1,
#  2,
#  3,
#  1,
#  2,
#  3,
#  1,
# ...
